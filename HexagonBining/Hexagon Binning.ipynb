# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %matplotlib inline

# %%
census = pd.read_excel(r"/Users/luciablanc/Documents/AAESTUDIOS/UOC_Máster_Data_Science/4t_Semestre/Visualización_datos/PEC2/Hexagon_Bining/Indiancensus_Geospatialindexing.xlsx")
print(census)
# Out:
#               State        District   Latitude  Longitude  Population_2001  \
# 0    Andhra Pradesh       Anantapur  14.312066  77.460158          3640478
# 1    Andhra Pradesh        Chittoor  13.331093  78.927639          3745875
# 2    Andhra Pradesh   East Godavari  16.782718  82.243207          4901420
# 3    Andhra Pradesh          Guntur  15.884926  80.586576          4465144
# 4    Andhra Pradesh         Krishna  16.143873  81.148051          4187841
# ..              ...             ...        ...        ...              ...
# 426     West Bengal         Kolkata  22.550581  88.352765          4572876
# 427     West Bengal          Maldah  25.080268  88.171917          3290468
# 428     West Bengal     Murshidabad  24.259507  88.168169          5866569
# 429     West Bengal           Nadia  23.564110  88.582930          4604827
# 430     West Bengal  Uttar Dinajpur  26.044619  88.235952          2441794
#
#      Population_2011
# 0            4081148
# 1            4174064
# ...

# %%
# Hexplots
census.plot(kind="hexbin", x="Longitude", y="Population_2011")
# Out:
# <Axes: xlabel='Longitude', ylabel='Population_2011'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'census' with columns: 'Longitude', 'Latitude', and 'Population_2011'

plt.figure(figsize=(10, 8))
plt.hexbin(x=census['Longitude'], y=census['Latitude'], C=census['Population_2011'], gridsize=11, cmap='YlOrRd')
plt.colorbar(label='Population in 2011')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('The Geospatial Indian Index Population in 2011')

plt.show()
